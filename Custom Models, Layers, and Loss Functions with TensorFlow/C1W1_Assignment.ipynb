# %% [markdown]
# # Week 1: Multiple Output Models using the Keras Functional API
#
# Welcome to the first programming assignment of the course! Your task will be to use the Keras functional API to train a model to predict two outputs. For this lab, you will use the **[Wine Quality Dataset](https://archive.ics.uci.edu/ml/datasets/Wine+Quality)** from the **UCI machine learning repository**. It has separate datasets for red wine and white wine.
#
# Normally, the wines are classified into one of the quality ratings specified in the attributes. In this exercise, you will combine the two datasets to predict the wine quality and whether the wine is red or white solely from the attributes.
#
# You will model wine quality estimations as a regression problem and wine type detection as a binary classification problem.
#
# #### Please complete sections that are marked **(TODO)**

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

import utils

# %% [markdown]
# ## Load Dataset
#
#
# You will now download the dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php).
#
# ### Pre-process the white wine dataset (TODO)
# You will add a new column named `is_red` in your dataframe to indicate if the wine is white or red.
# - In the white wine dataset, you will fill the column `is_red` with  zeros (0).

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# URL of the white wine dataset
URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'

# load the dataset from the URL
white_df = pd.read_csv(URL, sep=";")

# fill the `is_red` column with zeros.
white_df["is_red"] = 0

# keep only the first of duplicate items
white_df = white_df.drop_duplicates(keep='first')

# %%
# You can click `File -> Open` in the menu above and open the `utils.py` file 
# in case you want to inspect the unit tests being used for each graded function.

utils.test_white_df(white_df)
# Out:
#  All public tests passed

# %%
print(white_df.alcohol[0])
print(white_df.alcohol[100])

# EXPECTED OUTPUT
# 8.8
# 9.1
# Out:
# 8.8
# 9.1

# %% [markdown]
# ### Pre-process the red wine dataset (TODO)
# - In the red wine dataset, you will fill in the column `is_red` with ones (1).

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# URL of the red wine dataset
URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'

# load the dataset from the URL
red_df = pd.read_csv(URL, sep=";")

# fill the `is_red` column with ones.
red_df["is_red"] = 1

# keep only the first of duplicate items
red_df = red_df.drop_duplicates(keep='first')

# %%
utils.test_red_df(red_df)
# Out:
#  All public tests passed

# %%
print(red_df.alcohol[0])
print(red_df.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 10.2
# Out:
# 9.4
# 10.2

# %% [markdown]
# ### Concatenate the datasets
#
# Next, concatenate the red and white wine dataframes.

# %%
df = pd.concat([red_df, white_df], ignore_index=True)

# %%
print(df.alcohol[0])
print(df.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 9.5
# Out:
# 9.4
# 9.5

# %%
# NOTE: In a real-world scenario, you should shuffle the data.
# YOU ARE NOT going to do that here because we want to test
# with deterministic data. But if you want the code to do it,
# it's in the commented line below:

#df = df.iloc[np.random.permutation(len(df))]

# %% [markdown]
# This will chart the quality of the wines.

# %%
df['quality'].hist(bins=20);

# %% [markdown]
# ### Imbalanced data (TODO)
# You can see from the plot above that the wine quality dataset is imbalanced.
# - Since there are very few observations with quality equal to 3, 4, 8 and 9, you can drop these observations from your dataset.
# - You can do this by removing data belonging to all classes except those > 4 and < 8.

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# get data with wine quality greater than 4 and less than 8
df = df[(df['quality'] > 4) & (df['quality'] < 8 )]

# reset index and drop the old one
df = df.reset_index(drop=True)

# %%
utils.test_df_drop(df)
# Out:
#  All public tests passed

# %%
print(df.alcohol[0])
print(df.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 10.9
# Out:
# 9.4
# 10.9

# %% [markdown]
# You can plot again to see the new range of data and quality

# %%
df['quality'].hist(bins=20);

# %% [markdown]
# ### Train Test Split (TODO)
#
# Next, you can split the datasets into training, test and validation datasets.
# - The data frame should be split 80:20 into `train` and `test` sets.
# - The resulting `train` should then be split 80:20 into `train` and `val` sets.
# - The `train_test_split` parameter `test_size` takes a float value that ranges between 0. and 1, and represents the proportion of the dataset that is allocated to the test set.  The rest of the data is allocated to the training set.

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# Please do not change the random_state parameter. This is needed for grading.

# split df into 80:20 train and test sets
train, test = train_test_split(df, test_size=0.2, random_state = 1)
                               
# split train into 80:20 train and val sets
train, val = train_test_split(train, test_size=0.2, random_state = 1)

# %%
utils.test_data_sizes(train.size, test.size, val.size)
# Out:
#  All public tests passed

# %% [markdown]
# Here's where you can explore the training stats. You can pop the labels 'is_red' and 'quality' from the data as these will be used as the labels

# %%
train_stats = train.describe()
train_stats.pop('is_red')
train_stats.pop('quality')
train_stats = train_stats.transpose()

# %% [markdown]
# Explore the training stats!

# %%
train_stats
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         3155.0    7.221616   1.325297  3.80000   6.40000
# volatile acidity      3155.0    0.338929   0.162476  0.08000   0.23000
# citric acid           3155.0    0.321569   0.147970  0.00000   0.25000
# residual sugar        3155.0    5.155911   4.639632  0.60000   1.80000
# chlorides             3155.0    0.056976   0.036802  0.01200   0.03800
# free sulfur dioxide   3155.0   30.388590  17.236784  1.00000  17.00000
# total sulfur dioxide  3155.0  115.062282  56.706617  6.00000  75.00000
# density               3155.0    0.994633   0.003005  0.98711   0.99232
# pH                    3155.0    3.223201   0.161272  2.72000   3.11000
# sulphates             3155.0    0.534051   0.149149  0.22000   0.43000
# alcohol               3155.0   10.504466   1.154654  8.50000   9.50000
#
#                             50%       75%        max
# fixed acidity           7.00000    7.7000   15.60000
# volatile acidity        0.29000    0.4000    1.24000
# citric acid             0.31000    0.4000    1.66000
# residual sugar          2.80000    7.6500   65.80000
# chlorides               0.04700    0.0660    0.61100
# free sulfur dioxide    28.00000   41.0000  131.00000
# total sulfur dioxide  117.00000  156.0000  344.00000
# density                 0.99481    0.9968    1.03898
# pH                      3.21000    3.3300    4.01000
# sulphates               0.51000    0.6000    1.95000
# alcohol                10.30000   11.3000   14.00000

# %% [markdown]
# ### Get the labels (TODO)
#
# The features and labels are currently in the same dataframe.
# - You will want to store the label columns `is_red` and `quality` separately from the feature columns.
# - The following function, `format_output`, gets these two columns from the dataframe (it's given to you).
# - `format_output` also formats the data into numpy arrays.
# - Please use the `format_output` and apply it to the `train`, `val` and `test` sets to get dataframes for the labels.

# %%
def format_output(data):
    is_red = data.pop('is_red')
    is_red = np.array(is_red)
    quality = data.pop('quality')
    quality = np.array(quality)
    return (quality, is_red)

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# format the output of the train set
train_Y = format_output(train)

# format the output of the val set
val_Y = format_output(val)
    
# format the output of the test set
test_Y = format_output(test)

# %%
utils.test_format_output(df, train_Y, val_Y, test_Y)
# Out:
#  All public tests passed

# %% [markdown]
# Notice that after you get the labels, the `train`, `val` and `test` dataframes no longer contain the label columns, and contain just the feature columns.
# - This is because you used `.pop` in the `format_output` function.

# %%
train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 225             7.5              0.65         0.18             7.0      0.088
# 3557            6.3              0.27         0.29            12.2      0.044
# 3825            8.8              0.27         0.25             5.0      0.024
# 1740            6.4              0.45         0.07             1.1      0.030
# 1221            7.2              0.53         0.13             2.0      0.058
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 225                  27.0                  94.0  0.99915  3.38       0.77
# 3557                 59.0                 196.0  0.99782  3.14       0.40
# 3825                 52.0                  99.0  0.99250  2.87       0.49
# 1740                 10.0                 131.0  0.99050  2.97       0.28
# 1221                 18.0                  22.0  0.99573  3.21       0.68
#
#       alcohol
# 225       9.4
# 3557      8.8
# 3825     11.4
# 1740     10.8
# 1221      9.9

# %% [markdown]
# ### Normalize the data (TODO)
#
# Next, you can normalize the data, x, using the formula:
# $$x_{norm} = \frac{x - \mu}{\sigma}$$
# - The `norm` function is defined for you.
# - Please apply the `norm` function to normalize the dataframes that contains the feature columns of `train`, `val` and `test` sets.

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# normalize the train set
norm_train_X = norm(train)
    
# normalize the val set
norm_val_X = norm(val)
    
# normalize the test set
norm_test_X = norm(test)

# %%
utils.test_norm(norm_train_X, norm_val_X, norm_test_X, train, val, test)
# Out:
#  All public tests passed

# %% [markdown]
# ## Define the Model (TODO)
#
# Define the model using the functional API. The base model will be 2 `Dense` layers of 128 neurons each, and have the `'relu'` activation.
# - Check out the documentation for [tf.keras.layers.Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



def base_model(inputs):
    
    # connect a Dense layer with 128 neurons and a relu activation
    x = Dense(128, activation='relu')(inputs)
    
    # connect another Dense layer with 128 neurons and a relu activation
    x = Dense(128, activation='relu')(x)
    return x

# %%
utils.test_base_model(base_model)
# Out:
#  All public tests passed

# %% [markdown]
# # Define output layers of the model (TODO)
#
# You will add output layers to the base model.
# - The model will need two outputs.
#
# One output layer will predict wine quality, which is a numeric value.
# - Define a `Dense` layer with 1 neuron.
# - Since this is a regression output, the activation can be left as its default value `None`.
#
# The other output layer will predict the wine type, which is either red `1` or not red `0` (white).
# - Define a `Dense` layer with 1 neuron.
# - Since there are two possible categories, you can use a sigmoid activation for binary classification.
#
# Define the `Model`
# - Define the `Model` object, and set the following parameters:
#   - `inputs`: pass in the inputs to the model as a list.
#   - `outputs`: pass in a list of the outputs that you just defined: wine quality, then wine type.
#   - **Note**: please list the wine quality before wine type in the outputs, as this will affect the calculated loss if you choose the other order.

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



def final_model(inputs):
    
    # get the base model
    x = base_model(inputs)

    # connect the output Dense layer for regression
    wine_quality = Dense(units='1', name='wine_quality')(x)

    # connect the output Dense layer for classification. this will use a sigmoid activation.
    wine_type = Dense(units='1', activation='sigmoid', name='wine_type')(x)

    # define the model using the input and output layers
    model = Model(inputs=inputs, outputs=[wine_quality, wine_type])

    return model

# %%
utils.test_final_model(final_model)
# Out:
#  All public tests passed

# %% [markdown]
# ## Compiling the Model
#
# Next, compile the model. When setting the loss parameter of `model.compile`, you're setting the loss for each of the two outputs (wine quality and wine type).
#
# To set more than one loss, use a dictionary of key-value pairs.
# - You can look at the docs for the losses [here](https://www.tensorflow.org/api_docs/python/tf/keras/losses#functions).
#     - **Note**: For the desired spelling, please look at the "Functions" section of the documentation and not the "classes" section on that same page.
# - wine_type: Since you will be performing binary classification on wine type, you should use the binary crossentropy loss function for it.  Please pass this in as a string.
#   - **Hint**, this should be all lowercase.  In the documentation, you'll see this under the "Functions" section, not the "Classes" section.
# - wine_quality: since this is a regression output, use the mean squared error.  Please pass it in as a string, all lowercase.
#   - **Hint**: You may notice that there are two aliases for mean squared error.  Please use the shorter name.
#
#
# You will also set the metric for each of the two outputs.  Again, to set metrics for two or more outputs, use a dictionary with key value pairs.
# - The metrics documentation is linked [here](https://www.tensorflow.org/api_docs/python/tf/keras/metrics).
# - For the wine type, please set it to accuracy as a string, all lowercase.
# - For wine quality, please use the root mean squared error.  Instead of a string, you'll set it to an instance of the class [RootMeanSquaredError](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/RootMeanSquaredError), which belongs to the tf.keras.metrics module.
#
# **Note**: If you see the error message
# >Exception: wine quality loss function is incorrect.
#
# - Please also check your other losses and metrics, as the error may be caused by the other three key-value pairs and not the wine quality loss.

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



inputs = tf.keras.layers.Input(shape=(11,))
rms = tf.keras.optimizers.RMSprop(lr=0.0001)
model = final_model(inputs)

model.compile(optimizer=rms, 
              loss = {'wine_type' : 'binary_crossentropy',
                      'wine_quality' : 'mse'
                     },
              metrics = {'wine_type' : 'accuracy',
                         'wine_quality': tf.keras.metrics.RootMeanSquaredError()
                       }
             )

# %%
utils.test_model_compile(model)
# Out:
#  All public tests passed

# %% [markdown]
# ## Training the Model
#
# Fit the model to the training inputs and outputs.
# - Check the documentation for [model.fit](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit).
# - Remember to use the normalized training set as inputs.
# - For the validation data, please use the normalized validation set.

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



history = model.fit(norm_train_X, train_Y,
                    epochs = 180, validation_data=(norm_val_X, val_Y))
# Out:
# Train on 3155 samples, validate on 789 samples
# Epoch 1/180
# 3155/3155 [==============================] - 1s 375us/sample - loss: 30.3139 - wine_quality_loss: 29.6216 - wine_type_loss: 0.6697 - wine_quality_root_mean_squared_error: 5.4446 - wine_type_accuracy: 0.6983 - val_loss: 23.4081 - val_wine_quality_loss: 22.7572 - val_wine_type_loss: 0.6642 - val_wine_quality_root_mean_squared_error: 4.7692 - val_wine_type_accuracy: 0.7110
# Epoch 2/180
# 3155/3155 [==============================] - 0s 107us/sample - loss: 17.3261 - wine_quality_loss: 16.6440 - wine_type_loss: 0.6444 - wine_quality_root_mean_squared_error: 4.0843 - wine_type_accuracy: 0.7357 - val_loss: 11.8499 - val_wine_quality_loss: 11.2564 - val_wine_type_loss: 0.6331 - val_wine_quality_root_mean_squared_error: 3.3493 - val_wine_type_accuracy: 0.7326
# Epoch 3/180
# 3155/3155 [==============================] - 0s 95us/sample - loss: 7.8223 - wine_quality_loss: 7.2044 - wine_type_loss: 0.5997 - wine_quality_root_mean_squared_error: 2.6874 - wine_type_accuracy: 0.7442 - val_loss: 4.6630 - val_wine_quality_loss: 4.1589 - val_wine_type_loss: 0.5736 - val_wine_quality_root_mean_squared_error: 2.0225 - val_wine_type_accuracy: 0.7338
# Epoch 4/180
# 3155/3155 [==============================] - 0s 95us/sample - loss: 3.4988 - wine_quality_loss: 2.9740 - wine_type_loss: 0.5188 - wine_quality_root_mean_squared_error: 1.7261 - wine_type_accuracy: 0.7442 - val_loss: 2.7240 - val_wine_quality_loss: 2.3013 - val_wine_type_loss: 0.4772 - val_wine_quality_root_mean_squared_error: 1.4992 - val_wine_type_accuracy: 0.7338
# Epoch 5/180
# 3155/3155 [==============================] - 0s 77us/sample - loss: 2.5393 - wine_quality_loss: 2.1121 - wine_type_loss: 0.4260 - wine_quality_root_mean_squared_error: 1.4538 - wine_type_accuracy: 0.7708 - val_loss: 2.2875 - val_wine_quality_loss: 1.9299 - val_wine_type_loss: 0.3905 - val_wine_quality_root_mean_squared_error: 1.3776 - val_wine_type_accuracy: 0.8175
# Epoch 6/180
# 3155/3155 [==============================] - 0s 78us/sample - loss: 2.1832 - wine_quality_loss: 1.8301 - wine_type_loss: 0.3499 - wine_quality_root_mean_squared_error: 1.3538 - wine_type_accuracy: 0.8802 - val_loss: 1.9892 - val_wine_quality_loss: 1.6890 - val_wine_type_loss: 0.3223 - val_wine_quality_root_mean_squared_error: 1.2913 - val_wine_type_accuracy: 0.9240
# Epoch 7/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 1.9140 - wine_quality_loss: 1.6271 - wine_type_loss: 0.2851 - wine_quality_root_mean_squared_error: 1.2762 - wine_type_accuracy: 0.9452 - val_loss: 1.7617 - val_wine_quality_loss: 1.5142 - val_wine_type_loss: 0.2605 - val_wine_quality_root_mean_squared_error: 1.2254 - val_wine_type_accuracy: 0.9632
# Epoch 8/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 1.7093 - wine_quality_loss: 1.4773 - wine_type_loss: 0.2314 - wine_quality_root_mean_squared_error: 1.2159 - wine_type_accuracy: 0.9689 - val_loss: 1.5735 - val_wine_quality_loss: 1.3728 - val_wine_type_loss: 0.2084 - val_wine_quality_root_mean_squared_error: 1.1685 - val_wine_type_accuracy: 0.9810
# Epoch 9/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 1.5437 - wine_quality_loss: 1.3566 - wine_type_loss: 0.1851 - wine_quality_root_mean_squared_error: 1.1655 - wine_type_accuracy: 0.9832 - val_loss: 1.4430 - val_wine_quality_loss: 1.2791 - val_wine_type_loss: 0.1677 - val_wine_quality_root_mean_squared_error: 1.1294 - val_wine_type_accuracy: 0.9886
# Epoch 10/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 1.4159 - wine_quality_loss: 1.2632 - wine_type_loss: 0.1515 - wine_quality_root_mean_squared_error: 1.1244 - wine_type_accuracy: 0.9857 - val_loss: 1.3191 - val_wine_quality_loss: 1.1844 - val_wine_type_loss: 0.1369 - val_wine_quality_root_mean_squared_error: 1.0873 - val_wine_type_accuracy: 0.9899
# Epoch 11/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 1.3158 - wine_quality_loss: 1.1882 - wine_type_loss: 0.1257 - wine_quality_root_mean_squared_error: 1.0908 - wine_type_accuracy: 0.9883 - val_loss: 1.2334 - val_wine_quality_loss: 1.1198 - val_wine_type_loss: 0.1145 - val_wine_quality_root_mean_squared_error: 1.0577 - val_wine_type_accuracy: 0.9899
# Epoch 12/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 1.2247 - wine_quality_loss: 1.1207 - wine_type_loss: 0.1069 - wine_quality_root_mean_squared_error: 1.0573 - wine_type_accuracy: 0.9886 - val_loss: 1.1453 - val_wine_quality_loss: 1.0480 - val_wine_type_loss: 0.0977 - val_wine_quality_root_mean_squared_error: 1.0235 - val_wine_type_accuracy: 0.9899
# Epoch 13/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 1.1426 - wine_quality_loss: 1.0494 - wine_type_loss: 0.0926 - wine_quality_root_mean_squared_error: 1.0246 - wine_type_accuracy: 0.9899 - val_loss: 1.0779 - val_wine_quality_loss: 0.9930 - val_wine_type_loss: 0.0844 - val_wine_quality_root_mean_squared_error: 0.9967 - val_wine_type_accuracy: 0.9899
# Epoch 14/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 1.0726 - wine_quality_loss: 0.9903 - wine_type_loss: 0.0813 - wine_quality_root_mean_squared_error: 0.9956 - wine_type_accuracy: 0.9892 - val_loss: 1.0221 - val_wine_quality_loss: 0.9466 - val_wine_type_loss: 0.0747 - val_wine_quality_root_mean_squared_error: 0.9732 - val_wine_type_accuracy: 0.9911
# Epoch 15/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 1.0078 - wine_quality_loss: 0.9338 - wine_type_loss: 0.0728 - wine_quality_root_mean_squared_error: 0.9669 - wine_type_accuracy: 0.9905 - val_loss: 0.9416 - val_wine_quality_loss: 0.8735 - val_wine_type_loss: 0.0672 - val_wine_quality_root_mean_squared_error: 0.9350 - val_wine_type_accuracy: 0.9911
# Epoch 16/180
# 3155/3155 [==============================] - 0s 77us/sample - loss: 0.9570 - wine_quality_loss: 0.8893 - wine_type_loss: 0.0665 - wine_quality_root_mean_squared_error: 0.9437 - wine_type_accuracy: 0.9908 - val_loss: 0.9166 - val_wine_quality_loss: 0.8543 - val_wine_type_loss: 0.0609 - val_wine_quality_root_mean_squared_error: 0.9249 - val_wine_type_accuracy: 0.9911
# Epoch 17/180
# 3155/3155 [==============================] - 0s 93us/sample - loss: 0.9049 - wine_quality_loss: 0.8428 - wine_type_loss: 0.0609 - wine_quality_root_mean_squared_error: 0.9187 - wine_type_accuracy: 0.9911 - val_loss: 0.8645 - val_wine_quality_loss: 0.8069 - val_wine_type_loss: 0.0561 - val_wine_quality_root_mean_squared_error: 0.8989 - val_wine_type_accuracy: 0.9911
# Epoch 18/180
# 3155/3155 [==============================] - 0s 93us/sample - loss: 0.8570 - wine_quality_loss: 0.8004 - wine_type_loss: 0.0566 - wine_quality_root_mean_squared_error: 0.8946 - wine_type_accuracy: 0.9914 - val_loss: 0.8166 - val_wine_quality_loss: 0.7629 - val_wine_type_loss: 0.0524 - val_wine_quality_root_mean_squared_error: 0.8741 - val_wine_type_accuracy: 0.9924
# Epoch 19/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.8145 - wine_quality_loss: 0.7606 - wine_type_loss: 0.0531 - wine_quality_root_mean_squared_error: 0.8725 - wine_type_accuracy: 0.9911 - val_loss: 0.7797 - val_wine_quality_loss: 0.7288 - val_wine_type_loss: 0.0492 - val_wine_quality_root_mean_squared_error: 0.8545 - val_wine_type_accuracy: 0.9924
# Epoch 20/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.7759 - wine_quality_loss: 0.7257 - wine_type_loss: 0.0502 - wine_quality_root_mean_squared_error: 0.8518 - wine_type_accuracy: 0.9918 - val_loss: 0.7358 - val_wine_quality_loss: 0.6877 - val_wine_type_loss: 0.0466 - val_wine_quality_root_mean_squared_error: 0.8300 - val_wine_type_accuracy: 0.9924
# Epoch 21/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.7383 - wine_quality_loss: 0.6944 - wine_type_loss: 0.0477 - wine_quality_root_mean_squared_error: 0.8310 - wine_type_accuracy: 0.9918 - val_loss: 0.7123 - val_wine_quality_loss: 0.6666 - val_wine_type_loss: 0.0444 - val_wine_quality_root_mean_squared_error: 0.8171 - val_wine_type_accuracy: 0.9924
# Epoch 22/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.7033 - wine_quality_loss: 0.6562 - wine_type_loss: 0.0457 - wine_quality_root_mean_squared_error: 0.8109 - wine_type_accuracy: 0.9918 - val_loss: 0.6808 - val_wine_quality_loss: 0.6366 - val_wine_type_loss: 0.0424 - val_wine_quality_root_mean_squared_error: 0.7988 - val_wine_type_accuracy: 0.9924
# Epoch 23/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.6742 - wine_quality_loss: 0.6302 - wine_type_loss: 0.0438 - wine_quality_root_mean_squared_error: 0.7939 - wine_type_accuracy: 0.9921 - val_loss: 0.6501 - val_wine_quality_loss: 0.6074 - val_wine_type_loss: 0.0409 - val_wine_quality_root_mean_squared_error: 0.7803 - val_wine_type_accuracy: 0.9911
# Epoch 24/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.6435 - wine_quality_loss: 0.6011 - wine_type_loss: 0.0427 - wine_quality_root_mean_squared_error: 0.7753 - wine_type_accuracy: 0.9921 - val_loss: 0.6122 - val_wine_quality_loss: 0.5709 - val_wine_type_loss: 0.0396 - val_wine_quality_root_mean_squared_error: 0.7565 - val_wine_type_accuracy: 0.9911
# Epoch 25/180
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.6147 - wine_quality_loss: 0.5746 - wine_type_loss: 0.0410 - wine_quality_root_mean_squared_error: 0.7574 - wine_type_accuracy: 0.9921 - val_loss: 0.5913 - val_wine_quality_loss: 0.5513 - val_wine_type_loss: 0.0387 - val_wine_quality_root_mean_squared_error: 0.7431 - val_wine_type_accuracy: 0.9911
# Epoch 26/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.5901 - wine_quality_loss: 0.5505 - wine_type_loss: 0.0418 - wine_quality_root_mean_squared_error: 0.7417 - wine_type_accuracy: 0.9921 - val_loss: 0.5680 - val_wine_quality_loss: 0.5289 - val_wine_type_loss: 0.0377 - val_wine_quality_root_mean_squared_error: 0.7280 - val_wine_type_accuracy: 0.9911
# Epoch 27/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.5705 - wine_quality_loss: 0.5326 - wine_type_loss: 0.0389 - wine_quality_root_mean_squared_error: 0.7291 - wine_type_accuracy: 0.9927 - val_loss: 0.5431 - val_wine_quality_loss: 0.5048 - val_wine_type_loss: 0.0368 - val_wine_quality_root_mean_squared_error: 0.7113 - val_wine_type_accuracy: 0.9924
# Epoch 28/180
# 3155/3155 [==============================] - 0s 93us/sample - loss: 0.5480 - wine_quality_loss: 0.5102 - wine_type_loss: 0.0393 - wine_quality_root_mean_squared_error: 0.7142 - wine_type_accuracy: 0.9933 - val_loss: 0.5182 - val_wine_quality_loss: 0.4808 - val_wine_type_loss: 0.0361 - val_wine_quality_root_mean_squared_error: 0.6941 - val_wine_type_accuracy: 0.9924
# Epoch 29/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.5278 - wine_quality_loss: 0.4909 - wine_type_loss: 0.0369 - wine_quality_root_mean_squared_error: 0.7005 - wine_type_accuracy: 0.9933 - val_loss: 0.5039 - val_wine_quality_loss: 0.4674 - val_wine_type_loss: 0.0352 - val_wine_quality_root_mean_squared_error: 0.6844 - val_wine_type_accuracy: 0.9924
# Epoch 30/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.5087 - wine_quality_loss: 0.4736 - wine_type_loss: 0.0361 - wine_quality_root_mean_squared_error: 0.6873 - wine_type_accuracy: 0.9937 - val_loss: 0.4954 - val_wine_quality_loss: 0.4589 - val_wine_type_loss: 0.0347 - val_wine_quality_root_mean_squared_error: 0.6785 - val_wine_type_accuracy: 0.9924
# Epoch 31/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.4922 - wine_quality_loss: 0.4577 - wine_type_loss: 0.0373 - wine_quality_root_mean_squared_error: 0.6757 - wine_type_accuracy: 0.9937 - val_loss: 0.4765 - val_wine_quality_loss: 0.4414 - val_wine_type_loss: 0.0340 - val_wine_quality_root_mean_squared_error: 0.6649 - val_wine_type_accuracy: 0.9924
# Epoch 32/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.4763 - wine_quality_loss: 0.4413 - wine_type_loss: 0.0348 - wine_quality_root_mean_squared_error: 0.6644 - wine_type_accuracy: 0.9940 - val_loss: 0.4569 - val_wine_quality_loss: 0.4216 - val_wine_type_loss: 0.0338 - val_wine_quality_root_mean_squared_error: 0.6502 - val_wine_type_accuracy: 0.9924
# Epoch 33/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.4618 - wine_quality_loss: 0.4277 - wine_type_loss: 0.0344 - wine_quality_root_mean_squared_error: 0.6538 - wine_type_accuracy: 0.9937 - val_loss: 0.4435 - val_wine_quality_loss: 0.4089 - val_wine_type_loss: 0.0333 - val_wine_quality_root_mean_squared_error: 0.6402 - val_wine_type_accuracy: 0.9924
# Epoch 34/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.4502 - wine_quality_loss: 0.4161 - wine_type_loss: 0.0337 - wine_quality_root_mean_squared_error: 0.6453 - wine_type_accuracy: 0.9937 - val_loss: 0.4358 - val_wine_quality_loss: 0.4017 - val_wine_type_loss: 0.0330 - val_wine_quality_root_mean_squared_error: 0.6344 - val_wine_type_accuracy: 0.9924
# Epoch 35/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.4388 - wine_quality_loss: 0.4057 - wine_type_loss: 0.0333 - wine_quality_root_mean_squared_error: 0.6368 - wine_type_accuracy: 0.9940 - val_loss: 0.4257 - val_wine_quality_loss: 0.3922 - val_wine_type_loss: 0.0325 - val_wine_quality_root_mean_squared_error: 0.6268 - val_wine_type_accuracy: 0.9924
# Epoch 36/180
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.4281 - wine_quality_loss: 0.3955 - wine_type_loss: 0.0328 - wine_quality_root_mean_squared_error: 0.6286 - wine_type_accuracy: 0.9940 - val_loss: 0.4134 - val_wine_quality_loss: 0.3797 - val_wine_type_loss: 0.0322 - val_wine_quality_root_mean_squared_error: 0.6171 - val_wine_type_accuracy: 0.9924
# Epoch 37/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.4182 - wine_quality_loss: 0.3856 - wine_type_loss: 0.0324 - wine_quality_root_mean_squared_error: 0.6210 - wine_type_accuracy: 0.9940 - val_loss: 0.4121 - val_wine_quality_loss: 0.3787 - val_wine_type_loss: 0.0319 - val_wine_quality_root_mean_squared_error: 0.6163 - val_wine_type_accuracy: 0.9924
# Epoch 38/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.4100 - wine_quality_loss: 0.3791 - wine_type_loss: 0.0319 - wine_quality_root_mean_squared_error: 0.6149 - wine_type_accuracy: 0.9949 - val_loss: 0.4008 - val_wine_quality_loss: 0.3680 - val_wine_type_loss: 0.0317 - val_wine_quality_root_mean_squared_error: 0.6073 - val_wine_type_accuracy: 0.9937
# Epoch 39/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.4038 - wine_quality_loss: 0.3725 - wine_type_loss: 0.0319 - wine_quality_root_mean_squared_error: 0.6100 - wine_type_accuracy: 0.9943 - val_loss: 0.4011 - val_wine_quality_loss: 0.3684 - val_wine_type_loss: 0.0314 - val_wine_quality_root_mean_squared_error: 0.6077 - val_wine_type_accuracy: 0.9937
# Epoch 40/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3977 - wine_quality_loss: 0.3659 - wine_type_loss: 0.0313 - wine_quality_root_mean_squared_error: 0.6053 - wine_type_accuracy: 0.9946 - val_loss: 0.3953 - val_wine_quality_loss: 0.3626 - val_wine_type_loss: 0.0312 - val_wine_quality_root_mean_squared_error: 0.6031 - val_wine_type_accuracy: 0.9937
# Epoch 41/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3914 - wine_quality_loss: 0.3607 - wine_type_loss: 0.0310 - wine_quality_root_mean_squared_error: 0.6002 - wine_type_accuracy: 0.9943 - val_loss: 0.3920 - val_wine_quality_loss: 0.3595 - val_wine_type_loss: 0.0310 - val_wine_quality_root_mean_squared_error: 0.6005 - val_wine_type_accuracy: 0.9937
# Epoch 42/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3863 - wine_quality_loss: 0.3554 - wine_type_loss: 0.0307 - wine_quality_root_mean_squared_error: 0.5962 - wine_type_accuracy: 0.9946 - val_loss: 0.3783 - val_wine_quality_loss: 0.3464 - val_wine_type_loss: 0.0307 - val_wine_quality_root_mean_squared_error: 0.5892 - val_wine_type_accuracy: 0.9937
# Epoch 43/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3811 - wine_quality_loss: 0.3505 - wine_type_loss: 0.0304 - wine_quality_root_mean_squared_error: 0.5921 - wine_type_accuracy: 0.9946 - val_loss: 0.3800 - val_wine_quality_loss: 0.3483 - val_wine_type_loss: 0.0305 - val_wine_quality_root_mean_squared_error: 0.5909 - val_wine_type_accuracy: 0.9937
# Epoch 44/180
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.3772 - wine_quality_loss: 0.3472 - wine_type_loss: 0.0302 - wine_quality_root_mean_squared_error: 0.5890 - wine_type_accuracy: 0.9946 - val_loss: 0.3678 - val_wine_quality_loss: 0.3363 - val_wine_type_loss: 0.0304 - val_wine_quality_root_mean_squared_error: 0.5806 - val_wine_type_accuracy: 0.9937
# Epoch 45/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.3731 - wine_quality_loss: 0.3425 - wine_type_loss: 0.0299 - wine_quality_root_mean_squared_error: 0.5858 - wine_type_accuracy: 0.9946 - val_loss: 0.3673 - val_wine_quality_loss: 0.3358 - val_wine_type_loss: 0.0302 - val_wine_quality_root_mean_squared_error: 0.5803 - val_wine_type_accuracy: 0.9937
# Epoch 46/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3697 - wine_quality_loss: 0.3395 - wine_type_loss: 0.0297 - wine_quality_root_mean_squared_error: 0.5830 - wine_type_accuracy: 0.9946 - val_loss: 0.3686 - val_wine_quality_loss: 0.3371 - val_wine_type_loss: 0.0302 - val_wine_quality_root_mean_squared_error: 0.5814 - val_wine_type_accuracy: 0.9937
# Epoch 47/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3654 - wine_quality_loss: 0.3358 - wine_type_loss: 0.0294 - wine_quality_root_mean_squared_error: 0.5795 - wine_type_accuracy: 0.9946 - val_loss: 0.3732 - val_wine_quality_loss: 0.3423 - val_wine_type_loss: 0.0301 - val_wine_quality_root_mean_squared_error: 0.5855 - val_wine_type_accuracy: 0.9937
# Epoch 48/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3628 - wine_quality_loss: 0.3335 - wine_type_loss: 0.0292 - wine_quality_root_mean_squared_error: 0.5775 - wine_type_accuracy: 0.9946 - val_loss: 0.3649 - val_wine_quality_loss: 0.3340 - val_wine_type_loss: 0.0298 - val_wine_quality_root_mean_squared_error: 0.5786 - val_wine_type_accuracy: 0.9937
# Epoch 49/180
# 3155/3155 [==============================] - 0s 93us/sample - loss: 0.3597 - wine_quality_loss: 0.3307 - wine_type_loss: 0.0290 - wine_quality_root_mean_squared_error: 0.5750 - wine_type_accuracy: 0.9946 - val_loss: 0.3557 - val_wine_quality_loss: 0.3249 - val_wine_type_loss: 0.0298 - val_wine_quality_root_mean_squared_error: 0.5706 - val_wine_type_accuracy: 0.9937
# Epoch 50/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3578 - wine_quality_loss: 0.3287 - wine_type_loss: 0.0288 - wine_quality_root_mean_squared_error: 0.5735 - wine_type_accuracy: 0.9949 - val_loss: 0.3600 - val_wine_quality_loss: 0.3292 - val_wine_type_loss: 0.0296 - val_wine_quality_root_mean_squared_error: 0.5744 - val_wine_type_accuracy: 0.9937
# Epoch 51/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3557 - wine_quality_loss: 0.3267 - wine_type_loss: 0.0302 - wine_quality_root_mean_squared_error: 0.5718 - wine_type_accuracy: 0.9949 - val_loss: 0.3560 - val_wine_quality_loss: 0.3254 - val_wine_type_loss: 0.0295 - val_wine_quality_root_mean_squared_error: 0.5711 - val_wine_type_accuracy: 0.9937
# Epoch 52/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3527 - wine_quality_loss: 0.3242 - wine_type_loss: 0.0284 - wine_quality_root_mean_squared_error: 0.5694 - wine_type_accuracy: 0.9949 - val_loss: 0.3577 - val_wine_quality_loss: 0.3272 - val_wine_type_loss: 0.0294 - val_wine_quality_root_mean_squared_error: 0.5726 - val_wine_type_accuracy: 0.9937
# Epoch 53/180
# 3155/3155 [==============================] - 0s 77us/sample - loss: 0.3511 - wine_quality_loss: 0.3234 - wine_type_loss: 0.0282 - wine_quality_root_mean_squared_error: 0.5682 - wine_type_accuracy: 0.9946 - val_loss: 0.3556 - val_wine_quality_loss: 0.3249 - val_wine_type_loss: 0.0293 - val_wine_quality_root_mean_squared_error: 0.5709 - val_wine_type_accuracy: 0.9937
# Epoch 54/180
# 3155/3155 [==============================] - 0s 93us/sample - loss: 0.3486 - wine_quality_loss: 0.3200 - wine_type_loss: 0.0281 - wine_quality_root_mean_squared_error: 0.5661 - wine_type_accuracy: 0.9949 - val_loss: 0.3581 - val_wine_quality_loss: 0.3275 - val_wine_type_loss: 0.0293 - val_wine_quality_root_mean_squared_error: 0.5731 - val_wine_type_accuracy: 0.9937
# Epoch 55/180
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.3465 - wine_quality_loss: 0.3186 - wine_type_loss: 0.0279 - wine_quality_root_mean_squared_error: 0.5644 - wine_type_accuracy: 0.9949 - val_loss: 0.3497 - val_wine_quality_loss: 0.3195 - val_wine_type_loss: 0.0291 - val_wine_quality_root_mean_squared_error: 0.5659 - val_wine_type_accuracy: 0.9937
# Epoch 56/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3450 - wine_quality_loss: 0.3177 - wine_type_loss: 0.0277 - wine_quality_root_mean_squared_error: 0.5633 - wine_type_accuracy: 0.9949 - val_loss: 0.3499 - val_wine_quality_loss: 0.3197 - val_wine_type_loss: 0.0290 - val_wine_quality_root_mean_squared_error: 0.5662 - val_wine_type_accuracy: 0.9937
# Epoch 57/180
# 3155/3155 [==============================] - 0s 77us/sample - loss: 0.3440 - wine_quality_loss: 0.3160 - wine_type_loss: 0.0275 - wine_quality_root_mean_squared_error: 0.5624 - wine_type_accuracy: 0.9949 - val_loss: 0.3487 - val_wine_quality_loss: 0.3186 - val_wine_type_loss: 0.0288 - val_wine_quality_root_mean_squared_error: 0.5653 - val_wine_type_accuracy: 0.9937
# Epoch 58/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3416 - wine_quality_loss: 0.3144 - wine_type_loss: 0.0273 - wine_quality_root_mean_squared_error: 0.5606 - wine_type_accuracy: 0.9949 - val_loss: 0.3518 - val_wine_quality_loss: 0.3214 - val_wine_type_loss: 0.0289 - val_wine_quality_root_mean_squared_error: 0.5679 - val_wine_type_accuracy: 0.9937
# Epoch 59/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3406 - wine_quality_loss: 0.3139 - wine_type_loss: 0.0272 - wine_quality_root_mean_squared_error: 0.5597 - wine_type_accuracy: 0.9949 - val_loss: 0.3544 - val_wine_quality_loss: 0.3245 - val_wine_type_loss: 0.0288 - val_wine_quality_root_mean_squared_error: 0.5702 - val_wine_type_accuracy: 0.9937
# Epoch 60/180
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.3383 - wine_quality_loss: 0.3115 - wine_type_loss: 0.0271 - wine_quality_root_mean_squared_error: 0.5579 - wine_type_accuracy: 0.9949 - val_loss: 0.3459 - val_wine_quality_loss: 0.3160 - val_wine_type_loss: 0.0288 - val_wine_quality_root_mean_squared_error: 0.5628 - val_wine_type_accuracy: 0.9937
# Epoch 61/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3382 - wine_quality_loss: 0.3107 - wine_type_loss: 0.0268 - wine_quality_root_mean_squared_error: 0.5579 - wine_type_accuracy: 0.9949 - val_loss: 0.3449 - val_wine_quality_loss: 0.3149 - val_wine_type_loss: 0.0287 - val_wine_quality_root_mean_squared_error: 0.5620 - val_wine_type_accuracy: 0.9937
# Epoch 62/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3369 - wine_quality_loss: 0.3105 - wine_type_loss: 0.0267 - wine_quality_root_mean_squared_error: 0.5569 - wine_type_accuracy: 0.9949 - val_loss: 0.3557 - val_wine_quality_loss: 0.3255 - val_wine_type_loss: 0.0287 - val_wine_quality_root_mean_squared_error: 0.5716 - val_wine_type_accuracy: 0.9937
# Epoch 63/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3348 - wine_quality_loss: 0.3083 - wine_type_loss: 0.0266 - wine_quality_root_mean_squared_error: 0.5551 - wine_type_accuracy: 0.9949 - val_loss: 0.3464 - val_wine_quality_loss: 0.3166 - val_wine_type_loss: 0.0285 - val_wine_quality_root_mean_squared_error: 0.5635 - val_wine_type_accuracy: 0.9937
# Epoch 64/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3347 - wine_quality_loss: 0.3078 - wine_type_loss: 0.0264 - wine_quality_root_mean_squared_error: 0.5551 - wine_type_accuracy: 0.9949 - val_loss: 0.3521 - val_wine_quality_loss: 0.3221 - val_wine_type_loss: 0.0285 - val_wine_quality_root_mean_squared_error: 0.5685 - val_wine_type_accuracy: 0.9937
# Epoch 65/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.3330 - wine_quality_loss: 0.3064 - wine_type_loss: 0.0263 - wine_quality_root_mean_squared_error: 0.5538 - wine_type_accuracy: 0.9949 - val_loss: 0.3549 - val_wine_quality_loss: 0.3250 - val_wine_type_loss: 0.0285 - val_wine_quality_root_mean_squared_error: 0.5710 - val_wine_type_accuracy: 0.9937
# Epoch 66/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3315 - wine_quality_loss: 0.3057 - wine_type_loss: 0.0261 - wine_quality_root_mean_squared_error: 0.5526 - wine_type_accuracy: 0.9949 - val_loss: 0.3492 - val_wine_quality_loss: 0.3195 - val_wine_type_loss: 0.0282 - val_wine_quality_root_mean_squared_error: 0.5662 - val_wine_type_accuracy: 0.9937
# Epoch 67/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3295 - wine_quality_loss: 0.3034 - wine_type_loss: 0.0259 - wine_quality_root_mean_squared_error: 0.5509 - wine_type_accuracy: 0.9949 - val_loss: 0.3537 - val_wine_quality_loss: 0.3242 - val_wine_type_loss: 0.0283 - val_wine_quality_root_mean_squared_error: 0.5702 - val_wine_type_accuracy: 0.9937
# Epoch 68/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3297 - wine_quality_loss: 0.3036 - wine_type_loss: 0.0260 - wine_quality_root_mean_squared_error: 0.5511 - wine_type_accuracy: 0.9949 - val_loss: 0.3432 - val_wine_quality_loss: 0.3137 - val_wine_type_loss: 0.0282 - val_wine_quality_root_mean_squared_error: 0.5609 - val_wine_type_accuracy: 0.9937
# Epoch 69/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3289 - wine_quality_loss: 0.3037 - wine_type_loss: 0.0257 - wine_quality_root_mean_squared_error: 0.5505 - wine_type_accuracy: 0.9949 - val_loss: 0.3469 - val_wine_quality_loss: 0.3175 - val_wine_type_loss: 0.0281 - val_wine_quality_root_mean_squared_error: 0.5642 - val_wine_type_accuracy: 0.9937
# Epoch 70/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3284 - wine_quality_loss: 0.3028 - wine_type_loss: 0.0256 - wine_quality_root_mean_squared_error: 0.5502 - wine_type_accuracy: 0.9949 - val_loss: 0.3500 - val_wine_quality_loss: 0.3206 - val_wine_type_loss: 0.0281 - val_wine_quality_root_mean_squared_error: 0.5670 - val_wine_type_accuracy: 0.9937
# Epoch 71/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3262 - wine_quality_loss: 0.3004 - wine_type_loss: 0.0255 - wine_quality_root_mean_squared_error: 0.5484 - wine_type_accuracy: 0.9949 - val_loss: 0.3515 - val_wine_quality_loss: 0.3221 - val_wine_type_loss: 0.0281 - val_wine_quality_root_mean_squared_error: 0.5684 - val_wine_type_accuracy: 0.9937
# Epoch 72/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3262 - wine_quality_loss: 0.3007 - wine_type_loss: 0.0253 - wine_quality_root_mean_squared_error: 0.5485 - wine_type_accuracy: 0.9949 - val_loss: 0.3456 - val_wine_quality_loss: 0.3167 - val_wine_type_loss: 0.0280 - val_wine_quality_root_mean_squared_error: 0.5633 - val_wine_type_accuracy: 0.9937
# Epoch 73/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3239 - wine_quality_loss: 0.2989 - wine_type_loss: 0.0252 - wine_quality_root_mean_squared_error: 0.5465 - wine_type_accuracy: 0.9949 - val_loss: 0.3435 - val_wine_quality_loss: 0.3145 - val_wine_type_loss: 0.0279 - val_wine_quality_root_mean_squared_error: 0.5615 - val_wine_type_accuracy: 0.9937
# Epoch 74/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3242 - wine_quality_loss: 0.2994 - wine_type_loss: 0.0251 - wine_quality_root_mean_squared_error: 0.5468 - wine_type_accuracy: 0.9949 - val_loss: 0.3495 - val_wine_quality_loss: 0.3203 - val_wine_type_loss: 0.0278 - val_wine_quality_root_mean_squared_error: 0.5669 - val_wine_type_accuracy: 0.9937
# Epoch 75/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3237 - wine_quality_loss: 0.2983 - wine_type_loss: 0.0250 - wine_quality_root_mean_squared_error: 0.5465 - wine_type_accuracy: 0.9949 - val_loss: 0.3452 - val_wine_quality_loss: 0.3162 - val_wine_type_loss: 0.0278 - val_wine_quality_root_mean_squared_error: 0.5630 - val_wine_type_accuracy: 0.9937
# Epoch 76/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3227 - wine_quality_loss: 0.2973 - wine_type_loss: 0.0248 - wine_quality_root_mean_squared_error: 0.5457 - wine_type_accuracy: 0.9949 - val_loss: 0.3393 - val_wine_quality_loss: 0.3105 - val_wine_type_loss: 0.0277 - val_wine_quality_root_mean_squared_error: 0.5579 - val_wine_type_accuracy: 0.9937
# Epoch 77/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3212 - wine_quality_loss: 0.2962 - wine_type_loss: 0.0247 - wine_quality_root_mean_squared_error: 0.5444 - wine_type_accuracy: 0.9949 - val_loss: 0.3451 - val_wine_quality_loss: 0.3162 - val_wine_type_loss: 0.0277 - val_wine_quality_root_mean_squared_error: 0.5631 - val_wine_type_accuracy: 0.9937
# Epoch 78/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3208 - wine_quality_loss: 0.2968 - wine_type_loss: 0.0246 - wine_quality_root_mean_squared_error: 0.5441 - wine_type_accuracy: 0.9949 - val_loss: 0.3442 - val_wine_quality_loss: 0.3153 - val_wine_type_loss: 0.0277 - val_wine_quality_root_mean_squared_error: 0.5623 - val_wine_type_accuracy: 0.9937
# Epoch 79/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3206 - wine_quality_loss: 0.2962 - wine_type_loss: 0.0257 - wine_quality_root_mean_squared_error: 0.5441 - wine_type_accuracy: 0.9949 - val_loss: 0.3398 - val_wine_quality_loss: 0.3112 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5586 - val_wine_type_accuracy: 0.9937
# Epoch 80/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3188 - wine_quality_loss: 0.2944 - wine_type_loss: 0.0243 - wine_quality_root_mean_squared_error: 0.5426 - wine_type_accuracy: 0.9956 - val_loss: 0.3419 - val_wine_quality_loss: 0.3134 - val_wine_type_loss: 0.0275 - val_wine_quality_root_mean_squared_error: 0.5605 - val_wine_type_accuracy: 0.9937
# Epoch 81/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3184 - wine_quality_loss: 0.2941 - wine_type_loss: 0.0242 - wine_quality_root_mean_squared_error: 0.5424 - wine_type_accuracy: 0.9952 - val_loss: 0.3480 - val_wine_quality_loss: 0.3192 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5658 - val_wine_type_accuracy: 0.9937
# Epoch 82/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3172 - wine_quality_loss: 0.2930 - wine_type_loss: 0.0241 - wine_quality_root_mean_squared_error: 0.5413 - wine_type_accuracy: 0.9952 - val_loss: 0.3438 - val_wine_quality_loss: 0.3153 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5621 - val_wine_type_accuracy: 0.9937
# Epoch 83/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3165 - wine_quality_loss: 0.2928 - wine_type_loss: 0.0240 - wine_quality_root_mean_squared_error: 0.5408 - wine_type_accuracy: 0.9952 - val_loss: 0.3393 - val_wine_quality_loss: 0.3107 - val_wine_type_loss: 0.0273 - val_wine_quality_root_mean_squared_error: 0.5583 - val_wine_type_accuracy: 0.9937
# Epoch 84/180
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.3156 - wine_quality_loss: 0.2913 - wine_type_loss: 0.0239 - wine_quality_root_mean_squared_error: 0.5400 - wine_type_accuracy: 0.9952 - val_loss: 0.3481 - val_wine_quality_loss: 0.3197 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5660 - val_wine_type_accuracy: 0.9937
# Epoch 85/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3160 - wine_quality_loss: 0.2916 - wine_type_loss: 0.0238 - wine_quality_root_mean_squared_error: 0.5405 - wine_type_accuracy: 0.9956 - val_loss: 0.3408 - val_wine_quality_loss: 0.3124 - val_wine_type_loss: 0.0273 - val_wine_quality_root_mean_squared_error: 0.5595 - val_wine_type_accuracy: 0.9937
# Epoch 86/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3142 - wine_quality_loss: 0.2912 - wine_type_loss: 0.0237 - wine_quality_root_mean_squared_error: 0.5389 - wine_type_accuracy: 0.9956 - val_loss: 0.3475 - val_wine_quality_loss: 0.3193 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5655 - val_wine_type_accuracy: 0.9937
# Epoch 87/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3141 - wine_quality_loss: 0.2908 - wine_type_loss: 0.0235 - wine_quality_root_mean_squared_error: 0.5389 - wine_type_accuracy: 0.9956 - val_loss: 0.3504 - val_wine_quality_loss: 0.3220 - val_wine_type_loss: 0.0272 - val_wine_quality_root_mean_squared_error: 0.5682 - val_wine_type_accuracy: 0.9937
# Epoch 88/180
# 3155/3155 [==============================] - 0s 99us/sample - loss: 0.3137 - wine_quality_loss: 0.2904 - wine_type_loss: 0.0235 - wine_quality_root_mean_squared_error: 0.5386 - wine_type_accuracy: 0.9956 - val_loss: 0.3432 - val_wine_quality_loss: 0.3150 - val_wine_type_loss: 0.0272 - val_wine_quality_root_mean_squared_error: 0.5618 - val_wine_type_accuracy: 0.9937
# Epoch 89/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3130 - wine_quality_loss: 0.2893 - wine_type_loss: 0.0233 - wine_quality_root_mean_squared_error: 0.5382 - wine_type_accuracy: 0.9956 - val_loss: 0.3369 - val_wine_quality_loss: 0.3086 - val_wine_type_loss: 0.0271 - val_wine_quality_root_mean_squared_error: 0.5563 - val_wine_type_accuracy: 0.9937
# Epoch 90/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.3121 - wine_quality_loss: 0.2890 - wine_type_loss: 0.0232 - wine_quality_root_mean_squared_error: 0.5374 - wine_type_accuracy: 0.9956 - val_loss: 0.3403 - val_wine_quality_loss: 0.3120 - val_wine_type_loss: 0.0271 - val_wine_quality_root_mean_squared_error: 0.5593 - val_wine_type_accuracy: 0.9937
# Epoch 91/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3116 - wine_quality_loss: 0.2888 - wine_type_loss: 0.0231 - wine_quality_root_mean_squared_error: 0.5370 - wine_type_accuracy: 0.9959 - val_loss: 0.3360 - val_wine_quality_loss: 0.3079 - val_wine_type_loss: 0.0270 - val_wine_quality_root_mean_squared_error: 0.5556 - val_wine_type_accuracy: 0.9937
# Epoch 92/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3095 - wine_quality_loss: 0.2861 - wine_type_loss: 0.0230 - wine_quality_root_mean_squared_error: 0.5351 - wine_type_accuracy: 0.9959 - val_loss: 0.3455 - val_wine_quality_loss: 0.3174 - val_wine_type_loss: 0.0270 - val_wine_quality_root_mean_squared_error: 0.5641 - val_wine_type_accuracy: 0.9937
# Epoch 93/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3098 - wine_quality_loss: 0.2866 - wine_type_loss: 0.0229 - wine_quality_root_mean_squared_error: 0.5355 - wine_type_accuracy: 0.9959 - val_loss: 0.3427 - val_wine_quality_loss: 0.3148 - val_wine_type_loss: 0.0268 - val_wine_quality_root_mean_squared_error: 0.5618 - val_wine_type_accuracy: 0.9937
# Epoch 94/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3089 - wine_quality_loss: 0.2862 - wine_type_loss: 0.0228 - wine_quality_root_mean_squared_error: 0.5349 - wine_type_accuracy: 0.9956 - val_loss: 0.3413 - val_wine_quality_loss: 0.3132 - val_wine_type_loss: 0.0269 - val_wine_quality_root_mean_squared_error: 0.5604 - val_wine_type_accuracy: 0.9937
# Epoch 95/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3093 - wine_quality_loss: 0.2866 - wine_type_loss: 0.0239 - wine_quality_root_mean_squared_error: 0.5352 - wine_type_accuracy: 0.9959 - val_loss: 0.3419 - val_wine_quality_loss: 0.3139 - val_wine_type_loss: 0.0269 - val_wine_quality_root_mean_squared_error: 0.5609 - val_wine_type_accuracy: 0.9937
# Epoch 96/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3079 - wine_quality_loss: 0.2854 - wine_type_loss: 0.0226 - wine_quality_root_mean_squared_error: 0.5341 - wine_type_accuracy: 0.9959 - val_loss: 0.3421 - val_wine_quality_loss: 0.3140 - val_wine_type_loss: 0.0269 - val_wine_quality_root_mean_squared_error: 0.5611 - val_wine_type_accuracy: 0.9937
# Epoch 97/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3067 - wine_quality_loss: 0.2838 - wine_type_loss: 0.0225 - wine_quality_root_mean_squared_error: 0.5330 - wine_type_accuracy: 0.9959 - val_loss: 0.3414 - val_wine_quality_loss: 0.3136 - val_wine_type_loss: 0.0268 - val_wine_quality_root_mean_squared_error: 0.5605 - val_wine_type_accuracy: 0.9937
# Epoch 98/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3070 - wine_quality_loss: 0.2842 - wine_type_loss: 0.0226 - wine_quality_root_mean_squared_error: 0.5334 - wine_type_accuracy: 0.9959 - val_loss: 0.3374 - val_wine_quality_loss: 0.3096 - val_wine_type_loss: 0.0268 - val_wine_quality_root_mean_squared_error: 0.5570 - val_wine_type_accuracy: 0.9937
# Epoch 99/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3061 - wine_quality_loss: 0.2835 - wine_type_loss: 0.0223 - wine_quality_root_mean_squared_error: 0.5326 - wine_type_accuracy: 0.9959 - val_loss: 0.3401 - val_wine_quality_loss: 0.3124 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5595 - val_wine_type_accuracy: 0.9937
# Epoch 100/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3061 - wine_quality_loss: 0.2842 - wine_type_loss: 0.0222 - wine_quality_root_mean_squared_error: 0.5327 - wine_type_accuracy: 0.9959 - val_loss: 0.3410 - val_wine_quality_loss: 0.3134 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5603 - val_wine_type_accuracy: 0.9937
# Epoch 101/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3048 - wine_quality_loss: 0.2826 - wine_type_loss: 0.0222 - wine_quality_root_mean_squared_error: 0.5316 - wine_type_accuracy: 0.9959 - val_loss: 0.3475 - val_wine_quality_loss: 0.3197 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5661 - val_wine_type_accuracy: 0.9937
# Epoch 102/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3041 - wine_quality_loss: 0.2817 - wine_type_loss: 0.0220 - wine_quality_root_mean_squared_error: 0.5311 - wine_type_accuracy: 0.9959 - val_loss: 0.3365 - val_wine_quality_loss: 0.3089 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5564 - val_wine_type_accuracy: 0.9937
# Epoch 103/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3039 - wine_quality_loss: 0.2820 - wine_type_loss: 0.0218 - wine_quality_root_mean_squared_error: 0.5310 - wine_type_accuracy: 0.9959 - val_loss: 0.3463 - val_wine_quality_loss: 0.3185 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5652 - val_wine_type_accuracy: 0.9937
# Epoch 104/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3031 - wine_quality_loss: 0.2812 - wine_type_loss: 0.0218 - wine_quality_root_mean_squared_error: 0.5303 - wine_type_accuracy: 0.9959 - val_loss: 0.3436 - val_wine_quality_loss: 0.3159 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5627 - val_wine_type_accuracy: 0.9937
# Epoch 105/180
# 3155/3155 [==============================] - 0s 96us/sample - loss: 0.3021 - wine_quality_loss: 0.2811 - wine_type_loss: 0.0216 - wine_quality_root_mean_squared_error: 0.5295 - wine_type_accuracy: 0.9959 - val_loss: 0.3343 - val_wine_quality_loss: 0.3067 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5543 - val_wine_type_accuracy: 0.9937
# Epoch 106/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3023 - wine_quality_loss: 0.2801 - wine_type_loss: 0.0229 - wine_quality_root_mean_squared_error: 0.5297 - wine_type_accuracy: 0.9962 - val_loss: 0.3365 - val_wine_quality_loss: 0.3091 - val_wine_type_loss: 0.0264 - val_wine_quality_root_mean_squared_error: 0.5565 - val_wine_type_accuracy: 0.9937
# Epoch 107/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3020 - wine_quality_loss: 0.2801 - wine_type_loss: 0.0215 - wine_quality_root_mean_squared_error: 0.5296 - wine_type_accuracy: 0.9959 - val_loss: 0.3387 - val_wine_quality_loss: 0.3113 - val_wine_type_loss: 0.0265 - val_wine_quality_root_mean_squared_error: 0.5584 - val_wine_type_accuracy: 0.9937
# Epoch 108/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3016 - wine_quality_loss: 0.2801 - wine_type_loss: 0.0214 - wine_quality_root_mean_squared_error: 0.5293 - wine_type_accuracy: 0.9962 - val_loss: 0.3393 - val_wine_quality_loss: 0.3118 - val_wine_type_loss: 0.0265 - val_wine_quality_root_mean_squared_error: 0.5590 - val_wine_type_accuracy: 0.9937
# Epoch 109/180
# 3155/3155 [==============================] - 0s 93us/sample - loss: 0.2999 - wine_quality_loss: 0.2785 - wine_type_loss: 0.0214 - wine_quality_root_mean_squared_error: 0.5278 - wine_type_accuracy: 0.9962 - val_loss: 0.3358 - val_wine_quality_loss: 0.3083 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5557 - val_wine_type_accuracy: 0.9937
# Epoch 110/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3005 - wine_quality_loss: 0.2788 - wine_type_loss: 0.0212 - wine_quality_root_mean_squared_error: 0.5284 - wine_type_accuracy: 0.9962 - val_loss: 0.3354 - val_wine_quality_loss: 0.3080 - val_wine_type_loss: 0.0265 - val_wine_quality_root_mean_squared_error: 0.5556 - val_wine_type_accuracy: 0.9937
# Epoch 111/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.2996 - wine_quality_loss: 0.2783 - wine_type_loss: 0.0211 - wine_quality_root_mean_squared_error: 0.5277 - wine_type_accuracy: 0.9962 - val_loss: 0.3386 - val_wine_quality_loss: 0.3114 - val_wine_type_loss: 0.0263 - val_wine_quality_root_mean_squared_error: 0.5586 - val_wine_type_accuracy: 0.9937
# Epoch 112/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.2984 - wine_quality_loss: 0.2773 - wine_type_loss: 0.0216 - wine_quality_root_mean_squared_error: 0.5265 - wine_type_accuracy: 0.9962 - val_loss: 0.3379 - val_wine_quality_loss: 0.3109 - val_wine_type_loss: 0.0262 - val_wine_quality_root_mean_squared_error: 0.5580 - val_wine_type_accuracy: 0.9937
# Epoch 113/180
# 3155/3155 [==============================] - 0s 93us/sample - loss: 0.2965 - wine_quality_loss: 0.2750 - wine_type_loss: 0.0210 - wine_quality_root_mean_squared_error: 0.5249 - wine_type_accuracy: 0.9962 - val_loss: 0.3392 - val_wine_quality_loss: 0.3119 - val_wine_type_loss: 0.0262 - val_wine_quality_root_mean_squared_error: 0.5591 - val_wine_type_accuracy: 0.9937
# Epoch 114/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.2974 - wine_quality_loss: 0.2763 - wine_type_loss: 0.0208 - wine_quality_root_mean_squared_error: 0.5258 - wine_type_accuracy: 0.9962 - val_loss: 0.3436 - val_wine_quality_loss: 0.3165 - val_wine_type_loss: 0.0263 - val_wine_quality_root_mean_squared_error: 0.5630 - val_wine_type_accuracy: 0.9937
# Epoch 115/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2965 - wine_quality_loss: 0.2755 - wine_type_loss: 0.0207 - wine_quality_root_mean_squared_error: 0.5251 - wine_type_accuracy: 0.9962 - val_loss: 0.3362 - val_wine_quality_loss: 0.3089 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5565 - val_wine_type_accuracy: 0.9937
# Epoch 116/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2978 - wine_quality_loss: 0.2769 - wine_type_loss: 0.0221 - wine_quality_root_mean_squared_error: 0.5264 - wine_type_accuracy: 0.9962 - val_loss: 0.3347 - val_wine_quality_loss: 0.3074 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5552 - val_wine_type_accuracy: 0.9937
# Epoch 117/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.2968 - wine_quality_loss: 0.2760 - wine_type_loss: 0.0206 - wine_quality_root_mean_squared_error: 0.5255 - wine_type_accuracy: 0.9962 - val_loss: 0.3352 - val_wine_quality_loss: 0.3079 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5556 - val_wine_type_accuracy: 0.9937
# Epoch 118/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2955 - wine_quality_loss: 0.2746 - wine_type_loss: 0.0205 - wine_quality_root_mean_squared_error: 0.5243 - wine_type_accuracy: 0.9962 - val_loss: 0.3364 - val_wine_quality_loss: 0.3094 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5567 - val_wine_type_accuracy: 0.9937
# Epoch 119/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2960 - wine_quality_loss: 0.2752 - wine_type_loss: 0.0204 - wine_quality_root_mean_squared_error: 0.5250 - wine_type_accuracy: 0.9962 - val_loss: 0.3377 - val_wine_quality_loss: 0.3106 - val_wine_type_loss: 0.0260 - val_wine_quality_root_mean_squared_error: 0.5580 - val_wine_type_accuracy: 0.9937
# Epoch 120/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2949 - wine_quality_loss: 0.2741 - wine_type_loss: 0.0203 - wine_quality_root_mean_squared_error: 0.5239 - wine_type_accuracy: 0.9962 - val_loss: 0.3345 - val_wine_quality_loss: 0.3076 - val_wine_type_loss: 0.0260 - val_wine_quality_root_mean_squared_error: 0.5552 - val_wine_type_accuracy: 0.9937
# Epoch 121/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.2939 - wine_quality_loss: 0.2738 - wine_type_loss: 0.0202 - wine_quality_root_mean_squared_error: 0.5231 - wine_type_accuracy: 0.9962 - val_loss: 0.3370 - val_wine_quality_loss: 0.3099 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5573 - val_wine_type_accuracy: 0.9937
# Epoch 122/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.2930 - wine_quality_loss: 0.2724 - wine_type_loss: 0.0202 - wine_quality_root_mean_squared_error: 0.5223 - wine_type_accuracy: 0.9962 - val_loss: 0.3351 - val_wine_quality_loss: 0.3081 - val_wine_type_loss: 0.0260 - val_wine_quality_root_mean_squared_error: 0.5557 - val_wine_type_accuracy: 0.9937
# Epoch 123/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.2941 - wine_quality_loss: 0.2737 - wine_type_loss: 0.0201 - wine_quality_root_mean_squared_error: 0.5234 - wine_type_accuracy: 0.9962 - val_loss: 0.3353 - val_wine_quality_loss: 0.3084 - val_wine_type_loss: 0.0260 - val_wine_quality_root_mean_squared_error: 0.5559 - val_wine_type_accuracy: 0.9937
# Epoch 124/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2931 - wine_quality_loss: 0.2734 - wine_type_loss: 0.0200 - wine_quality_root_mean_squared_error: 0.5225 - wine_type_accuracy: 0.9962 - val_loss: 0.3347 - val_wine_quality_loss: 0.3078 - val_wine_type_loss: 0.0259 - val_wine_quality_root_mean_squared_error: 0.5554 - val_wine_type_accuracy: 0.9937
# Epoch 125/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.2922 - wine_quality_loss: 0.2719 - wine_type_loss: 0.0199 - wine_quality_root_mean_squared_error: 0.5218 - wine_type_accuracy: 0.9962 - val_loss: 0.3386 - val_wine_quality_loss: 0.3117 - val_wine_type_loss: 0.0259 - val_wine_quality_root_mean_squared_error: 0.5588 - val_wine_type_accuracy: 0.9937
# Epoch 126/180
# ...
# Epoch 140/180
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.2845 - wine_quality_loss: 0.2658 - wine_type_loss: 0.0187 - wine_quality_root_mean_squared_error: 0.5155 - wine_type_accuracy: 0.9965 - val_loss: 0.3593 - val_wine_quality_loss: 0.3323 - val_wine_type_loss: 0.0259 - val_wine_quality_root_mean_squared_error: 0.5770 - val_wine_type_accuracy: 0.9937
# Epoch 141/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.2843 - wine_quality_loss: 0.2656 - wine_type_loss: 0.0188 - wine_quality_root_mean_squared_error: 0.5152 - wine_type_accuracy: 0.9962 - val_loss: 0.3321 - val_wine_quality_loss: 0.3056 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5533 - val_wine_type_accuracy: 0.9937
# Epoch 142/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2843 - wine_quality_loss: 0.2657 - wine_type_loss: 0.0186 - wine_quality_root_mean_squared_error: 0.5154 - wine_type_accuracy: 0.9965 - val_loss: 0.3342 - val_wine_quality_loss: 0.3076 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5551 - val_wine_type_accuracy: 0.9937
# Epoch 143/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2838 - wine_quality_loss: 0.2658 - wine_type_loss: 0.0185 - wine_quality_root_mean_squared_error: 0.5150 - wine_type_accuracy: 0.9965 - val_loss: 0.3478 - val_wine_quality_loss: 0.3210 - val_wine_type_loss: 0.0258 - val_wine_quality_root_mean_squared_error: 0.5671 - val_wine_type_accuracy: 0.9937
# Epoch 144/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.2827 - wine_quality_loss: 0.2640 - wine_type_loss: 0.0184 - wine_quality_root_mean_squared_error: 0.5140 - wine_type_accuracy: 0.9965 - val_loss: 0.3447 - val_wine_quality_loss: 0.3180 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5645 - val_wine_type_accuracy: 0.9937
# Epoch 145/180
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.2830 - wine_quality_loss: 0.2644 - wine_type_loss: 0.0184 - wine_quality_root_mean_squared_error: 0.5143 - wine_type_accuracy: 0.9965 - val_loss: 0.3347 - val_wine_quality_loss: 0.3081 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5556 - val_wine_type_accuracy: 0.9937
# Epoch 146/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.2820 - wine_quality_loss: 0.2633 - wine_type_loss: 0.0183 - wine_quality_root_mean_squared_error: 0.5135 - wine_type_accuracy: 0.9965 - val_loss: 0.3389 - val_wine_quality_loss: 0.3122 - val_wine_type_loss: 0.0256 - val_wine_quality_root_mean_squared_error: 0.5594 - val_wine_type_accuracy: 0.9937
# Epoch 147/180
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.2826 - wine_quality_loss: 0.2639 - wine_type_loss: 0.0183 - wine_quality_root_mean_squared_error: 0.5141 - wine_type_accuracy: 0.9965 - val_loss: 0.3411 - val_wine_quality_loss: 0.3145 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5614 - val_wine_type_accuracy: 0.9937
# Epoch 148/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.2823 - wine_quality_loss: 0.2639 - wine_type_loss: 0.0182 - wine_quality_root_mean_squared_error: 0.5139 - wine_type_accuracy: 0.9965 - val_loss: 0.3329 - val_wine_quality_loss: 0.3064 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5540 - val_wine_type_accuracy: 0.9937
# Epoch 149/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2815 - wine_quality_loss: 0.2634 - wine_type_loss: 0.0181 - wine_quality_root_mean_squared_error: 0.5132 - wine_type_accuracy: 0.9965 - val_loss: 0.3390 - val_wine_quality_loss: 0.3125 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5594 - val_wine_type_accuracy: 0.9937
# Epoch 150/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2796 - wine_quality_loss: 0.2614 - wine_type_loss: 0.0180 - wine_quality_root_mean_squared_error: 0.5113 - wine_type_accuracy: 0.9965 - val_loss: 0.3424 - val_wine_quality_loss: 0.3160 - val_wine_type_loss: 0.0256 - val_wine_quality_root_mean_squared_error: 0.5626 - val_wine_type_accuracy: 0.9937
# Epoch 151/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.2805 - wine_quality_loss: 0.2625 - wine_type_loss: 0.0180 - wine_quality_root_mean_squared_error: 0.5123 - wine_type_accuracy: 0.9965 - val_loss: 0.3392 - val_wine_quality_loss: 0.3124 - val_wine_type_loss: 0.0256 - val_wine_quality_root_mean_squared_error: 0.5597 - val_wine_type_accuracy: 0.9937
# Epoch 152/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2796 - wine_quality_loss: 0.2618 - wine_type_loss: 0.0179 - wine_quality_root_mean_squared_error: 0.5115 - wine_type_accuracy: 0.9965 - val_loss: 0.3337 - val_wine_quality_loss: 0.3074 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5549 - val_wine_type_accuracy: 0.9937
# Epoch 153/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2797 - wine_quality_loss: 0.2623 - wine_type_loss: 0.0179 - wine_quality_root_mean_squared_error: 0.5117 - wine_type_accuracy: 0.9965 - val_loss: 0.3348 - val_wine_quality_loss: 0.3084 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5558 - val_wine_type_accuracy: 0.9937
# Epoch 154/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2784 - wine_quality_loss: 0.2607 - wine_type_loss: 0.0178 - wine_quality_root_mean_squared_error: 0.5104 - wine_type_accuracy: 0.9965 - val_loss: 0.3376 - val_wine_quality_loss: 0.3112 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5584 - val_wine_type_accuracy: 0.9937
# Epoch 155/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.2791 - wine_quality_loss: 0.2609 - wine_type_loss: 0.0177 - wine_quality_root_mean_squared_error: 0.5112 - wine_type_accuracy: 0.9965 - val_loss: 0.3371 - val_wine_quality_loss: 0.3105 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5579 - val_wine_type_accuracy: 0.9937
# Epoch 156/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2775 - wine_quality_loss: 0.2601 - wine_type_loss: 0.0177 - wine_quality_root_mean_squared_error: 0.5097 - wine_type_accuracy: 0.9965 - val_loss: 0.3376 - val_wine_quality_loss: 0.3110 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5584 - val_wine_type_accuracy: 0.9937
# Epoch 157/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2775 - wine_quality_loss: 0.2594 - wine_type_loss: 0.0176 - wine_quality_root_mean_squared_error: 0.5098 - wine_type_accuracy: 0.9965 - val_loss: 0.3346 - val_wine_quality_loss: 0.3081 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5557 - val_wine_type_accuracy: 0.9937
# Epoch 158/180
# 3155/3155 [==============================] - 0s 73us/sample - loss: 0.2772 - wine_quality_loss: 0.2597 - wine_type_loss: 0.0176 - wine_quality_root_mean_squared_error: 0.5095 - wine_type_accuracy: 0.9965 - val_loss: 0.3331 - val_wine_quality_loss: 0.3066 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5543 - val_wine_type_accuracy: 0.9937
# Epoch 159/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2774 - wine_quality_loss: 0.2601 - wine_type_loss: 0.0175 - wine_quality_root_mean_squared_error: 0.5098 - wine_type_accuracy: 0.9965 - val_loss: 0.3332 - val_wine_quality_loss: 0.3068 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5544 - val_wine_type_accuracy: 0.9937
# Epoch 160/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2759 - wine_quality_loss: 0.2592 - wine_type_loss: 0.0174 - wine_quality_root_mean_squared_error: 0.5084 - wine_type_accuracy: 0.9965 - val_loss: 0.3435 - val_wine_quality_loss: 0.3171 - val_wine_type_loss: 0.0256 - val_wine_quality_root_mean_squared_error: 0.5636 - val_wine_type_accuracy: 0.9937
# Epoch 161/180
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.2753 - wine_quality_loss: 0.2576 - wine_type_loss: 0.0173 - wine_quality_root_mean_squared_error: 0.5078 - wine_type_accuracy: 0.9965 - val_loss: 0.3328 - val_wine_quality_loss: 0.3066 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5541 - val_wine_type_accuracy: 0.9937
# Epoch 162/180
# 3155/3155 [==============================] - 0s 77us/sample - loss: 0.2758 - wine_quality_loss: 0.2585 - wine_type_loss: 0.0173 - wine_quality_root_mean_squared_error: 0.5084 - wine_type_accuracy: 0.9965 - val_loss: 0.3363 - val_wine_quality_loss: 0.3101 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5571 - val_wine_type_accuracy: 0.9937
# Epoch 163/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.2750 - wine_quality_loss: 0.2578 - wine_type_loss: 0.0183 - wine_quality_root_mean_squared_error: 0.5077 - wine_type_accuracy: 0.9965 - val_loss: 0.3306 - val_wine_quality_loss: 0.3043 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5521 - val_wine_type_accuracy: 0.9937
# Epoch 164/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2751 - wine_quality_loss: 0.2579 - wine_type_loss: 0.0171 - wine_quality_root_mean_squared_error: 0.5078 - wine_type_accuracy: 0.9965 - val_loss: 0.3330 - val_wine_quality_loss: 0.3068 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5543 - val_wine_type_accuracy: 0.9937
# Epoch 165/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2730 - wine_quality_loss: 0.2555 - wine_type_loss: 0.0171 - wine_quality_root_mean_squared_error: 0.5058 - wine_type_accuracy: 0.9965 - val_loss: 0.3435 - val_wine_quality_loss: 0.3168 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5636 - val_wine_type_accuracy: 0.9937
# Epoch 166/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.2736 - wine_quality_loss: 0.2570 - wine_type_loss: 0.0170 - wine_quality_root_mean_squared_error: 0.5064 - wine_type_accuracy: 0.9965 - val_loss: 0.3321 - val_wine_quality_loss: 0.3058 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5534 - val_wine_type_accuracy: 0.9937
# Epoch 167/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2733 - wine_quality_loss: 0.2571 - wine_type_loss: 0.0170 - wine_quality_root_mean_squared_error: 0.5062 - wine_type_accuracy: 0.9965 - val_loss: 0.3438 - val_wine_quality_loss: 0.3172 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5639 - val_wine_type_accuracy: 0.9937
# Epoch 168/180
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.2720 - wine_quality_loss: 0.2549 - wine_type_loss: 0.0169 - wine_quality_root_mean_squared_error: 0.5050 - wine_type_accuracy: 0.9965 - val_loss: 0.3340 - val_wine_quality_loss: 0.3078 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5551 - val_wine_type_accuracy: 0.9937
# Epoch 169/180
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.2724 - wine_quality_loss: 0.2555 - wine_type_loss: 0.0168 - wine_quality_root_mean_squared_error: 0.5055 - wine_type_accuracy: 0.9965 - val_loss: 0.3389 - val_wine_quality_loss: 0.3128 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5596 - val_wine_type_accuracy: 0.9937
# Epoch 170/180
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.2729 - wine_quality_loss: 0.2556 - wine_type_loss: 0.0168 - wine_quality_root_mean_squared_error: 0.5060 - wine_type_accuracy: 0.9965 - val_loss: 0.3358 - val_wine_quality_loss: 0.3095 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5567 - val_wine_type_accuracy: 0.9937
# Epoch 171/180
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.2712 - wine_quality_loss: 0.2543 - wine_type_loss: 0.0168 - wine_quality_root_mean_squared_error: 0.5043 - wine_type_accuracy: 0.9965 - val_loss: 0.3429 - val_wine_quality_loss: 0.3166 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5632 - val_wine_type_accuracy: 0.9937
# Epoch 172/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2698 - wine_quality_loss: 0.2539 - wine_type_loss: 0.0167 - wine_quality_root_mean_squared_error: 0.5031 - wine_type_accuracy: 0.9965 - val_loss: 0.3426 - val_wine_quality_loss: 0.3161 - val_wine_type_loss: 0.0253 - val_wine_quality_root_mean_squared_error: 0.5629 - val_wine_type_accuracy: 0.9949
# Epoch 173/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2706 - wine_quality_loss: 0.2539 - wine_type_loss: 0.0166 - wine_quality_root_mean_squared_error: 0.5039 - wine_type_accuracy: 0.9965 - val_loss: 0.3422 - val_wine_quality_loss: 0.3159 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5625 - val_wine_type_accuracy: 0.9937
# Epoch 174/180
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.2714 - wine_quality_loss: 0.2546 - wine_type_loss: 0.0166 - wine_quality_root_mean_squared_error: 0.5048 - wine_type_accuracy: 0.9965 - val_loss: 0.3360 - val_wine_quality_loss: 0.3097 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5571 - val_wine_type_accuracy: 0.9937
# Epoch 175/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2699 - wine_quality_loss: 0.2530 - wine_type_loss: 0.0165 - wine_quality_root_mean_squared_error: 0.5033 - wine_type_accuracy: 0.9965 - val_loss: 0.3365 - val_wine_quality_loss: 0.3102 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5575 - val_wine_type_accuracy: 0.9937
# Epoch 176/180
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.2701 - wine_quality_loss: 0.2539 - wine_type_loss: 0.0164 - wine_quality_root_mean_squared_error: 0.5036 - wine_type_accuracy: 0.9968 - val_loss: 0.3351 - val_wine_quality_loss: 0.3087 - val_wine_type_loss: 0.0254 - val_wine_quality_root_mean_squared_error: 0.5562 - val_wine_type_accuracy: 0.9937
# Epoch 177/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.2709 - wine_quality_loss: 0.2550 - wine_type_loss: 0.0164 - wine_quality_root_mean_squared_error: 0.5044 - wine_type_accuracy: 0.9965 - val_loss: 0.3410 - val_wine_quality_loss: 0.3148 - val_wine_type_loss: 0.0253 - val_wine_quality_root_mean_squared_error: 0.5616 - val_wine_type_accuracy: 0.9949
# Epoch 178/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2696 - wine_quality_loss: 0.2537 - wine_type_loss: 0.0168 - wine_quality_root_mean_squared_error: 0.5031 - wine_type_accuracy: 0.9965 - val_loss: 0.3350 - val_wine_quality_loss: 0.3090 - val_wine_type_loss: 0.0253 - val_wine_quality_root_mean_squared_error: 0.5563 - val_wine_type_accuracy: 0.9949
# Epoch 179/180
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.2687 - wine_quality_loss: 0.2526 - wine_type_loss: 0.0163 - wine_quality_root_mean_squared_error: 0.5024 - wine_type_accuracy: 0.9965 - val_loss: 0.3328 - val_wine_quality_loss: 0.3065 - val_wine_type_loss: 0.0253 - val_wine_quality_root_mean_squared_error: 0.5542 - val_wine_type_accuracy: 0.9949
# Epoch 180/180
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.2681 - wine_quality_loss: 0.2520 - wine_type_loss: 0.0163 - wine_quality_root_mean_squared_error: 0.5018 - wine_type_accuracy: 0.9965 - val_loss: 0.3376 - val_wine_quality_loss: 0.3114 - val_wine_type_loss: 0.0253 - val_wine_quality_root_mean_squared_error: 0.5585 - val_wine_type_accuracy: 0.9937

# %%
utils.test_history(history)
# Out:
#  All public tests passed

# %%
# Gather the training metrics
loss, wine_quality_loss, wine_type_loss, wine_quality_rmse, wine_type_accuracy = model.evaluate(x=norm_val_X, y=val_Y)

print()
print(f'loss: {loss}')
print(f'wine_quality_loss: {wine_quality_loss}')
print(f'wine_type_loss: {wine_type_loss}')
print(f'wine_quality_rmse: {wine_quality_rmse}')
print(f'wine_type_accuracy: {wine_type_accuracy}')

# EXPECTED VALUES
# ~ 0.30 - 0.38
# ~ 0.30 - 0.38
# ~ 0.018 - 0.030
# ~ 0.50 - 0.62
# ~ 0.97 - 1.0

# Example:
#0.3657050132751465
#0.3463745415210724
#0.019330406561493874
#0.5885359048843384
#0.9974651336669922
# Out:
# 789/789 [==============================] - 0s 22us/sample - loss: 0.3376 - wine_quality_loss: 0.3114 - wine_type_loss: 0.0253 - wine_quality_root_mean_squared_error: 0.5585 - wine_type_accuracy: 0.9937
#
# loss: 0.33755052644943556
# wine_quality_loss: 0.3113815188407898
# wine_type_loss: 0.025335540995001793
# wine_quality_rmse: 0.5584662556648254
# wine_type_accuracy: 0.9936628937721252

# %% [markdown]
# ## Analyze the Model Performance
#
# Note that the model has two outputs. The output at index 0 is quality and index 1 is wine type
#
# So, round the quality predictions to the nearest integer.

# %%
predictions = model.predict(norm_test_X)
quality_pred = predictions[0]
type_pred = predictions[1]

# %%
print(quality_pred[0])

# EXPECTED OUTPUT
# 5.6 - 6.0
# Out:
# [5.78293]

# %%
print(type_pred[0])
print(type_pred[944])

# EXPECTED OUTPUT
# A number close to zero
# A number close to or equal to 1
# Out:
# [0.00051587]
# [0.9999969]

# %% [markdown]
# ### Plot Utilities
#
# We define a few utilities to visualize the model performance.

# %%
def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0,ylim)
    plt.plot(history.history[metric_name],color='blue',label=metric_name)
    plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)
    plt.legend()
    plt.xlabel('# of epochs')
    plt.ylabel('metrics')

# %%
def plot_confusion_matrix(y_true, y_pred, title='', labels=[0,1]):
    cm = confusion_matrix(y_true, y_pred)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
          plt.text(j, i, format(cm[i, j], fmt),
                  horizontalalignment="center",
                  color="black" if cm[i, j] > thresh else "white")
    plt.show()

# %%
def plot_diff(y_true, y_pred, title = '' ):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.plot([-100, 100], [-100, 100])
    return plt

# %% [markdown]
# ### Plots for Metrics

# %%
plot_metrics('wine_quality_root_mean_squared_error', 'RMSE', ylim=2)

# %%
plot_metrics('wine_type_loss', 'Wine Type Loss', ylim=0.2)

# %% [markdown]
# ### Plots for Confusion Matrix
#
# Plot the confusion matrices for wine type. You can see that the model performs well for prediction of wine type from the confusion matrix and the loss metrics.

# %%
plot_confusion_matrix(test_Y[1], np.round(type_pred), title='Wine Type', labels = [0, 1])

# %%
scatter_plot = plot_diff(test_Y[0], quality_pred, title='Type')
